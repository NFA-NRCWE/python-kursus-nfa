# %% [markdown]
# # Python Course 2026 - Basic concepts

# %% [markdown]
# ## Exceuting code - where and how

# %% [markdown]
# ![{80163C1B-C683-4C0C-B394-B212CD06DBC1}.png](attachment:{80163C1B-C683-4C0C-B394-B212CD06DBC1}.png)

# %% [markdown]
# Where?
#
# - IDE (Integrated development environment)
#     - Spyder, VScode, Pycharm
# - .py vs .ipynb
#
# How?
#
# - From the top, fortunately
# - Input and output

# %% [markdown]
# ## Syntax

# %% [markdown]
# ![{ABFC3BE3-4903-49A8-8240-3CECDB48C5B6}.png](attachment:{ABFC3BE3-4903-49A8-8240-3CECDB48C5B6}.png)

# %% [markdown]
# Variables and types

# %%
a = 5
b = [5.1, 'hello']
print(type(a), type(b), type(b[0]), type(b[1]))
# Out:
# <class 'int'> <class 'list'> <class 'float'>

# %% [markdown]
# Case sensitive (and error messages)

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %% [markdown]
# Indexing and function calls (and comments)

# %%
#lets make a list we can index

L = [1,2,3,4,5]

print(L[0])
print(L[-1])
# Out:
# 1
# 5

# %% [markdown]
# Logic and loops (and indents)

# %%
for element in L:
    if element**2 > 10:
        print(element)
# Out:
# 4
# 5

# %%
c = 1

while c < 100:
    c = c + c
    print(c)
# Out:
# 2
# 4
# 8
# 16
# 32
# 64
# 128

# %% [markdown]
# Instances and built-in functions

# %%
str_var = "Hello Python people"

str_var.upper()
# Out:
# ' HELLO PYTHON PEOPLE'

# %% [markdown]
# Functions

# %%
def my_function(arg1, arg2):
    output = str(arg1) + " " + str(arg2)
    return output

my_function('Hello', 'Hallo')
# Out:
# 'Hello Hallo'

# %% [markdown]
# ## A simple script

# %% [markdown]
# ![{EF88DC68-869C-46F1-9BB7-25F3FB514310}.png](attachment:{EF88DC68-869C-46F1-9BB7-25F3FB514310}.png)

# %% [markdown]
# ## Packages

# %% [markdown]
# ![{BE508447-F9B0-4A3A-8280-4C159EE60900}.png](attachment:{BE508447-F9B0-4A3A-8280-4C159EE60900}.png)

# %%
import pandas as pd
import numpy as np
